# %%
# !git clone https://github.com/LizaDerb/probing_compositionality
# Out:
# Cloning into 'probing_compositionality'...
# remote: Enumerating objects: 393, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 393 (delta 47), reused 8 (delta 8), pack-reused 225
# Receiving objects: 100% (393/393), 146.83 MiB | 22.76 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
import pandas as pd

# %%
rand_pred = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_rand_pred.csv')
test_cls = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_test_cls.csv')
train_cls = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_train_cls.csv')
test_rand_vec = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_test_rand_vec.csv')
train_rand_vec = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_train_rand_vec.csv')
train_mean = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_train_mean.csv')
test_mean = pd.read_csv('/content/probing_compositionality/probing/russian_VP/results/res_test_mean.csv')

# %%
all_test = [rand_pred.iloc[:, 2:].mean(), test_rand_vec.iloc[:, 2:].mean(),
            test_cls.iloc[:, 2:].mean(), test_mean.iloc[:, 2:].mean()]
all_train = [train_rand_vec.iloc[:, 2:].mean(), train_cls.iloc[:, 2:].mean(), train_mean.iloc[:, 2:].mean()]

# %% [markdown]
# Распределение лейблов в тренировочном и тестовом датасетах (русский)
#
# \begin{array}{|c|c|} \hline
# & train & & test \\\hline
# I & 488 & 0,588 & 263 & 0,591 \\\hline
# L & 342 & 0,412 & 182 & 0,409 \\ \hline
# \end{array}

# %%
pd.concat(all_test, axis=1).rename(columns={0:'rand_pred', 1:'test_rand_vec', 2:'test_cls', 3:'test_mean'})
# Out:
#            rand_pred  test_rand_vec  test_cls  test_mean
# accuracy    0.498742       0.519820  0.776989   0.748854
# precision   0.408516       0.286797  0.719566   0.695784
# recall      0.503297       0.416703  0.747802   0.686154
# f1          0.450766       0.282019  0.732789   0.690866
# roc_auc     0.499443       0.503941  0.772494   0.739199

# %%
pd.concat(all_train, axis=1).rename(columns={0:'train_rand_vec', 1:'train_cls', 2:'train_mean'})
# Out:
#            train_rand_vec  train_cls  train_mean
# accuracy              1.0   0.996916         1.0
# precision             1.0   0.996730         1.0
# recall                1.0   0.995848         1.0
# f1                    1.0   0.996193         1.0
# roc_auc               1.0   0.996756         1.0
