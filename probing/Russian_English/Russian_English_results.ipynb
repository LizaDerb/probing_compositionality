# %%
# !git clone https://github.com/LizaDerb/probing_compositionality
# Out:
# Cloning into 'probing_compositionality'...
# remote: Enumerating objects: 356, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 356 (delta 39), reused 8 (delta 8), pack-reused 225
# Receiving objects: 100% (356/356), 139.91 MiB | 14.74 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Updating files: 100% (54/54), done.

# %%
import pandas as pd

# %%
rand_pred_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_rand_pred_eng.csv')
test_cls_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_cls_eng.csv')
train_cls_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_cls_eng.csv')
test_rand_vec_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_rand_vec_eng.csv')
train_rand_vec_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_rand_vec_eng.csv')
train_mean_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_mean_eng.csv')
test_mean_eng = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_mean_eng.csv')

# %%
all_test_eng = [rand_pred_eng.iloc[:, 2:].mean(), test_rand_vec_eng.iloc[:, 2:].mean(),
            test_cls_eng.iloc[:, 2:].mean(), test_mean_eng.iloc[:, 2:].mean()]
all_train_eng = [train_rand_vec_eng.iloc[:, 2:].mean(), train_cls_eng.iloc[:, 2:].mean(), train_mean_eng.iloc[:, 2:].mean()]

# %% [markdown]
# Распределение лейблов в тренировочном и тестовом датасетах (английский)
#
# \begin{array}{|c|c|} \hline
# & train & & test \\\hline
# I & 731 & 0,663 & 273 & 0,609 \\\hline
# L & 371 & 0,337 & 175 & 0,391 \\ \hline
# \end{array}

# %%
pd.concat(all_test_eng, axis=1).rename(columns={0:'rand_pred_eng', 1:'test_rand_vec_eng', 2:'test_cls_eng', 3:'test_mean_eng'})
# Out:
#            rand_pred_eng  test_rand_vec_eng  test_cls_eng  test_mean_eng
# accuracy        0.495938           0.469643      0.680848       0.679911
# precision       0.388003           0.412647      0.617383       0.613252
# recall          0.504457           0.725371      0.481714       0.489257
# f1              0.438393           0.491526      0.541045       0.544180
# roc_auc         0.497467           0.515543      0.645106       0.645691

# %%
pd.concat(all_train_eng, axis=1).rename(columns={0:'train_rand_vec_eng', 1:'train_cls_eng', 2:'train_mean_eng'})
# Out:
#            train_rand_vec_eng  train_cls_eng  train_mean_eng
# accuracy                  1.0            1.0             1.0
# precision                 1.0            1.0             1.0
# recall                    1.0            1.0             1.0
# f1                        1.0            1.0             1.0
# roc_auc                   1.0            1.0             1.0

# %%
rand_pred_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_rand_pred_rus.csv')
test_cls_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_cls_rus.csv')
train_cls_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_cls_rus.csv')
test_rand_vec_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_rand_vec_rus.csv')
train_rand_vec_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_rand_vec_rus.csv')
train_mean_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_train_mean_rus.csv')
test_mean_rus = pd.read_csv('/content/probing_compositionality/probing/Russian_English/results/res_test_mean_rus.csv')

# %%
all_test_rus = [rand_pred_rus.iloc[:, 2:].mean(), test_rand_vec_rus.iloc[:, 2:].mean(),
            test_cls_rus.iloc[:, 2:].mean(), test_mean_rus.iloc[:, 2:].mean()]
all_train_rus = [train_rand_vec_rus.iloc[:, 2:].mean(), train_cls_rus.iloc[:, 2:].mean(), train_mean_rus.iloc[:, 2:].mean()]

# %% [markdown]
# Распределение лейблов в тренировочном и тестовом датасетах (русский)
#
# \begin{array}{|c|c|} \hline
# & train & & test \\\hline
# I & 488 & 0,588 & 263 & 0,591 \\\hline
# L & 342 & 0,412 & 182 & 0,409 \\ \hline
# \end{array}

# %%
pd.concat(all_test_rus, axis=1).rename(columns={0:'rand_pred_rus', 1:'test_rand_vec_rus', 2:'test_cls_rus', 3:'test_mean_rus'})
# Out:
#            rand_pred_rus  test_rand_vec_rus  test_cls_rus  test_mean_rus
# accuracy        0.493708           0.456135      0.761438       0.764899
# precision       0.403292           0.318829      0.692187       0.694955
# recall          0.495714           0.433846      0.750659       0.758132
# f1              0.444520           0.337998      0.720182       0.725091
# roc_auc         0.494017           0.452703      0.759778       0.763857

# %%
pd.concat(all_train_rus, axis=1).rename(columns={0:'train_rand_vec_rus', 1:'train_cls_rus', 2:'train_mean_rus'})
# Out:
#            train_rand_vec_rus  train_cls_rus  train_mean_rus
# accuracy                  1.0            1.0             1.0
# precision                 1.0            1.0             1.0
# recall                    1.0            1.0             1.0
# f1                        1.0            1.0             1.0
# roc_auc                   1.0            1.0             1.0
