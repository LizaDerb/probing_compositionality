# %%
# !git clone https://github.com/LizaDerb/probing_compositionality
# Out:
# Cloning into 'probing_compositionality'...
# remote: Enumerating objects: 422, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 422 (delta 54), reused 8 (delta 8), pack-reused 225
# Receiving objects: 100% (422/422), 155.24 MiB | 15.47 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# Updating files: 100% (84/84), done.

# %%
import pandas as pd

# %%
rand_pred = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_rand_pred.csv')
test_cls = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_test_cls.csv')
train_cls = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_train_cls.csv')
test_rand_vec = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_test_rand_vec.csv')
train_rand_vec = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_train_rand_vec.csv')
train_mean = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_train_mean.csv')
test_mean = pd.read_csv('/content/probing_compositionality/probing/english_VP/results/res_test_mean.csv')

# %%
all_test = [rand_pred.iloc[:, 2:].mean(), test_rand_vec.iloc[:, 2:].mean(),
            test_cls.iloc[:, 2:].mean(), test_mean.iloc[:, 2:].mean()]
all_train = [train_rand_vec.iloc[:, 2:].mean(), train_cls.iloc[:, 2:].mean(), train_mean.iloc[:, 2:].mean()]

# %% [markdown]
# Распределение лейблов в тренировочном и тестовом датасетах (английский)
#
# \begin{array}{|c|c|} \hline
# & train & & test \\\hline
# I & 731 & 0,663 & 273 & 0,609 \\\hline
# L & 371 & 0,337 & 175 & 0,391 \\ \hline
# \end{array}

# %%
pd.concat(all_test, axis=1).rename(columns={0:'rand_pred', 1:'test_rand_vec', 2:'test_cls', 3:'test_mean'})
# Out:
#            rand_pred  test_rand_vec  test_cls  test_mean
# accuracy    0.502500       0.582589  0.699286   0.696429
# precision   0.392454       0.210238  0.638673   0.623513
# recall      0.500000       0.129143  0.531200   0.562857
# f1          0.439546       0.101371  0.579764   0.591540
# roc_auc     0.502051       0.501201  0.669116   0.672454

# %%
pd.concat(all_train, axis=1).rename(columns={0:'train_rand_vec', 1:'train_cls', 2:'train_mean'})
# Out:
#            train_rand_vec  train_cls  train_mean
# accuracy              1.0        1.0         1.0
# precision             1.0        1.0         1.0
# recall                1.0        1.0         1.0
# f1                    1.0        1.0         1.0
# roc_auc               1.0        1.0         1.0
